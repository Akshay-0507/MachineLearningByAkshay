# %%
import numpy as np
import time

# %% [markdown]
# #Showing the time take by normal list

# %%
a = [1,2,3,4,5] * 10000
start = time.time()
for i in range(len(a)):
    a[i] = a[i]*2

print("\nTime taken for operation:", time.time() - start)
# Out:
# Time taken for operation: 0.014219522476196289

# %% [markdown]
# Time take by Numpy lists:

# %%
a = [1,2,3,4,5] * 10000
#Creating a numpy array
b = np.array(a)
start = time.time()
new_b=b*2
print("\nTime taken for operation:", time.time() - start)
# Out:
# Time taken for operation: 0.0011446475982666016

# %% [markdown]
# #Memory Efficeincy of NUMPY(which is built using C)

# %%
a = [1,2,3,4,5]
b= np.array(a)
print("List size: ", sys.getsizeof(a))
print("NUMPY array size: ", b.nbytes)
# Out:
# List size:  104
# NUMPY array size:  40

# %%
#Method to check the itemsize, or size of each elements in byte
b.itemsize
# Out:
# 8
